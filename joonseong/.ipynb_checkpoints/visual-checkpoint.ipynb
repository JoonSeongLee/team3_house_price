# %%
maindf = pd.read_csv('../train.csv')
maindf.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1455         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1456         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1459         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
sns.jointplot(y="MSSubClass", x="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(x="OverallQual", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(x="YearBuilt", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(x="YearRemodAdd", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(x="MasVnrArea", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(x="BsmtFinSF2", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="598.8889047540268">

# %%
sns.jointplot(x="BsmtUnfSF", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="598.8889047540268">

# %%
sns.jointplot(x="TotalBsmtSF", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="1stFlrSF", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="2ndFlrSF", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="LowQualFinSF", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="GrLivArea", y="SalePrice", data=maindf)  #### GrLivArea =  1stFlrSF  + 2ndFlrSF
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="BsmtFullBath", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="FullBath", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="TotRmsAbvGrd", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="GarageYrBlt", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="GarageArea", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="WoodDeckSF", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="OpenPorchSF", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="EnclosedPorch", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
sns.jointplot(x="MoSold", y="SalePrice", data=maindf)
# Out:
# <img src="data:image/png;base64,..." width="539">

# %%
heat= maindf.corr()
heat
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
heat.to_csv('example.csv')

# %%
# %matplotlib inline


fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
sns.heatmap(heat.iloc[:, :], annot=True, linewidths=.5, ax=ax)

# %%
heat["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...
