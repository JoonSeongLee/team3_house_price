# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}
maindf = pd.read_csv('../train.csv')
maindf.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1455         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1456         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1459         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df1121 = maindf.iloc[:, 11:21]
df1121["SalePrice"] = maindf["SalePrice"]
print(df1121.columns)
df1121.tail()
# Out:
# Index(['LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'SalePrice'],
#       dtype='object')
#      LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 1455       Gtl      Gilbert       Norm       Norm     1Fam     2Story
# 1456       Gtl       NWAmes       Norm       Norm     1Fam     1Story
# 1457       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 1458       Gtl        NAmes       Norm       Norm     1Fam     1Story
# 1459       Gtl      Edwards       Norm       Norm     1Fam     1Story
#
#       OverallQual  OverallCond  YearBuilt  YearRemodAdd  SalePrice
# 1455            6            5       1999          2000     175000
# 1456            6            6       1978          1988     210000
# 1457            7            9       1941          2006     266500
# 1458            5            6       1950          1996     142125
# ...

# %%
df1121_HouseStyle = pd.DataFrame(df1121, columns=['HouseStyle'])
df1121_HouseStyle['SalePrice'] = df1121['SalePrice'] 
df1121_f2 = df1121.groupby(['HouseStyle']).size().reset_index(name='Counts')
df1121_f2
# Out:
#   HouseStyle  Counts
# 0     1.5Fin     154
# 1     1.5Unf      14
# 2     1Story     726
# 3     2.5Fin       8
# 4     2.5Unf      11
# 5     2Story     445
# 6     SFoyer      37
# 7       SLvl      65

# %%
def HouseStylegrade(data) :
    if data == '1.5Fin':
        return 8
    if data == '1.5Unf':
        return 7
    if data == '1Story':
        return 6
    if data == '2.5Fin':
        return 5
    if data == '2.5Unf':
        return 4
    if data == '2Story':
        return 3
    if data == 'SFoyer':
        return 2
    if data == 'SLvl':
        return 1
    else:
        return 0
df1121_HouseStyle['HouseStyle'] = df1121_HouseStyle['HouseStyle'].apply(HouseStylegrade)
sns.jointplot(x="HouseStyle", y="SalePrice", data=df1121_HouseStyle)

# %%
df1121_BldgType = pd.DataFrame(df1121, columns=['BldgType'])
df1121_BldgType['SalePrice'] = df1121['SalePrice'] 
df1121_f2 = df1121.groupby(['BldgType']).size().reset_index(name='Counts')
df1121_f2
# Out:
#   BldgType  Counts
# 0     1Fam    1220
# 1   2fmCon      31
# 2   Duplex      52
# 3    Twnhs      43
# 4   TwnhsE     114

# %%
def BldgTypegrade(data) :
    if data == '1Fam':
        return 5
    if data == '2fmCon':
        return 4
    if data == 'Duplex':
        return 3
    if data == 'Twnhs':
        return 2
    if data == 'TwnhsE':
        return 1
    else:
        return 0
df1121_BldgType['BldgType'] = df1121_BldgType['BldgType'].apply(BldgTypegrade)
sns.jointplot(x="BldgType", y="SalePrice", data=df1121_BldgType)

# %%
df1121_Condition2 = pd.DataFrame(df1121, columns=['Condition2'])
df1121_Condition2['SalePrice'] = df1121['SalePrice'] 
df1121_f2 = df1121.groupby(['Condition2']).size().reset_index(name='Counts')
df1121_f2
# Out:
#   Condition2  Counts
# 0     Artery       2
# 1      Feedr       6
# 2       Norm    1445
# 3       PosA       1
# 4       PosN       2
# 5       RRAe       1
# 6       RRAn       1
# 7       RRNn       2

# %%
def Condition2grade(data) :
    if data == 'Artery':
        return 8
    if data == 'Feedr':
        return 7
    if data == 'Norm':
        return 6
    if data == 'PosA':
        return 5
    if data == 'PosN':
        return 4
    if data == 'RRAe':
        return 3
    if data == 'RRAn':
        return 2
    if data == 'RRNn':
        return 1
    else:
        return 0
df1121_Condition2['Condition2'] = df1121_Condition2['Condition2'].apply(Condition2grade)
sns.jointplot(x="Condition2", y="SalePrice", data=df1121_Condition2)

# %%
df1121_Condition1 = pd.DataFrame(df1121, columns=['Condition1'])
df1121_Condition1['SalePrice'] = df1121['SalePrice'] 
df1121_f2 = df1121.groupby(['Condition1']).size().reset_index(name='Counts')
df1121_f2
# Out:
#   Condition1  Counts
# 0     Artery      48
# 1      Feedr      81
# 2       Norm    1260
# 3       PosA       8
# 4       PosN      19
# 5       RRAe      11
# 6       RRAn      26
# 7       RRNe       2
# 8       RRNn       5

# %%
def Condition1grade(data) :
    if data == 'Artery':
        return 8
    if data == 'Feedr':
        return 7
    if data == 'Norm':
        return 6
    if data == 'PosA':
        return 5
    if data == 'PosN':
        return 4
    if data == 'RRAe':
        return 3
    if data == 'RRAn':
        return 2
    if data == 'RRNn':
        return 1
    else:
        return 0
df1121_Condition1['Condition1'] = df1121_Condition1['Condition1'].apply(Condition1grade)
sns.jointplot(x="Condition1", y="SalePrice", data=df1121_Condition1)

# %%
df1121_Neighborhood = pd.DataFrame(df1121, columns=['Neighborhood'])
df1121_Neighborhood['SalePrice'] = df1121['SalePrice'] 
df1121_f2 = df1121.groupby(['Neighborhood']).size().reset_index(name='Counts')
df1121_f2
# Out:
#    Neighborhood  Counts
# 0       Blmngtn      17
# 1       Blueste       2
# 2        BrDale      16
# 3       BrkSide      58
# 4       ClearCr      28
# 5       CollgCr     150
# 6       Crawfor      51
# 7       Edwards     100
# 8       Gilbert      79
# 9        IDOTRR      37
# 10      MeadowV      17
# 11      Mitchel      49
# 12        NAmes     225
# 13      NPkVill       9
# 14       NWAmes      73
# 15      NoRidge      41
# 16      NridgHt      77
# 17      OldTown     113
# 18        SWISU      25
# 19       Sawyer      74
# 20      SawyerW      59
# 21      Somerst      86
# 22      StoneBr      25
# 23       Timber      38
# 24      Veenker      11

# %%
def Neighborhoodgrade(data) :
    if data == 'Blmngtn':
        return 25
    if data == 'Blueste':
        return 24
    if data == 'BrDale':
        return 23
    if data == 'BrkSide':
        return 22
    if data == 'ClearCr':
        return 21
    if data == 'CollgCr':
        return 20
    if data == 'Crawfor':
        return 19
    if data == 'Edwards':
        return 18
    if data == 'Gilbert':
        return 17
    if data == 'IDOTRR':
        return 16
    if data == 'MeadowV':
        return 15
    if data == 'Mitchel':
        return 14
    if data == 'NAmes':
        return 13
    if data == 'NPkVill':
        return 12
    if data == 'NWAmes':
        return 11
    if data == 'NoRidge':
        return 10
    if data == 'NridgHt':
        return 9
    if data == 'OldTown':
        return 8
    if data == 'SWISU':
        return 7
    if data == 'Sawyer':
        return 6
    if data == 'SawyerW':
        return 5
    if data == 'Somerst':
        return 4
    if data == 'StoneBr':
        return 3
    if data == 'Timber':
        return 2
    if data == 'Veenker':
        return 1
    else:
        return 0
df1121_Neighborhood['Neighborhood'] = df1121_Neighborhood['Neighborhood'].apply(Neighborhoodgrade)
sns.jointplot(x="Neighborhood", y="SalePrice", data=df1121_Neighborhood)

# %%
df1121_LandSlope = pd.DataFrame(df1121, columns=['LandSlope'])
df1121_LandSlope['SalePrice'] = df1121['SalePrice'] 
df1121_f2 = df1121.groupby(['LandSlope']).size().reset_index(name='Counts')
df1121_f2
# Out:
#   LandSlope  Counts
# 0       Gtl    1382
# 1       Mod      65
# 2       Sev      13

# %%
def LandSlopegrade(data) :
    if data == 'Gtl':
        return 3
    if data == 'Mod':
        return 2
    if data == 'Sev':
        return 1
    else:
        return 0
df1121_LandSlope['LandSlope'] = df1121_LandSlope['LandSlope'].apply(LandSlopegrade)
sns.jointplot(x="LandSlope", y="SalePrice", data=df1121_LandSlope)
