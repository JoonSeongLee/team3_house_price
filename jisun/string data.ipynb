# %%
plt.rcParams["figure.figsize"] = (15,6)

# %%
df_raw = pd.read_csv('../train.csv')
df_raw.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1455         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1456         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1459         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1455       0      8   2007        WD         Normal     175000
# 1456       0      2   2010        WD         Normal     210000
# 1457    2500      5   2010        WD         Normal     266500
# 1458       0      4   2010        WD         Normal     142125
# 1459       0      6   2008        WD         Normal     147500
#
# [5 rows x 81 columns]

# %%
# string인 column만 선별하기
def isstr(col):
    if type(col[0]) == str:
        return True
strcolum_name=[]
i=0
col_names = df_raw.columns
for col in col_names:
    if isstr(df_raw[col]):
        strcolum_name.append(i)
    i+=1
    
# SalePrice가 있는 col 포함 = 80번째
strcolum_name.append(80)

# %%
df_str = df_raw.iloc[:, strcolum_name]
df_str.tail()
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2    ...    KitchenQual Functional  \
# 1455      Gilbert       Norm       Norm    ...             TA        Typ
# 1456       NWAmes       Norm       Norm    ...             TA       Min1
# 1457      Crawfor       Norm       Norm    ...             Gd        Typ
# 1458        NAmes       Norm       Norm    ...             Gd        Typ
# 1459      Edwards       Norm       Norm    ...             TA        Typ
#
#      GarageType GarageFinish GarageQual GarageCond PavedDrive SaleType  \
# 1455     Attchd          RFn         TA         TA          Y       WD
# 1456     Attchd          Unf         TA         TA          Y       WD
# 1457     Attchd          RFn         TA         TA          Y       WD
# 1458     Attchd          Unf         TA         TA          Y       WD
# 1459     Attchd          Fin         TA         TA          Y       WD
#
#      SaleCondition SalePrice
# 1455        Normal    175000
# 1456        Normal    210000
# 1457        Normal    266500
# 1458        Normal    142125
# 1459        Normal    147500
#
# [5 rows x 39 columns]

# %%
df_new = df_str

col_names = df_new.columns[0:-1]
ls=[]
for col_name in col_names:
    df1 = pd.DataFrame(df_new, columns=[col_name,"SalePrice"])  
    df2 = df1.groupby([col_name])["SalePrice"].median().reset_index(name='Median').sort_values('Median').reset_index(drop=True)
    def isgrade(data) :
        for idx in range(len(df2)):
            if data == df2[col_name][idx]:
                return idx+1
    df_new[col_name + 'Grade'] = df_new[col_name].apply(isgrade)
    
df_new = df_new.iloc[:,39:]

df_new["SalePrice"] = df_str["SalePrice"]
df_new.tail()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#       MSZoningGrade  StreetGrade  LotShapeGrade  LandContourGrade  \
# 1455              4            2              1                 2
# 1456              4            2              1                 2
# 1457              4            2              1                 2
# 1458              4            2              1                 2
# 1459              4            2              1                 2
#
#       UtilitiesGrade  LotConfigGrade  LandSlopeGrade  NeighborhoodGrade  \
# 1455               2               1               1                 14
# 1456               2               1               1                 15
# 1457               2               1               1                 19
# 1458               2               1               1                 10
# 1459               2               1               1                  5
#
#       Condition1Grade  Condition2Grade    ...      KitchenQualGrade  \
# 1455                4                5    ...                     2
# 1456                4                5    ...                     2
# 1457                4                5    ...                     3
# 1458                4                5    ...                     3
# 1459                4                5    ...                     2
#
#       FunctionalGrade  GarageTypeGrade  GarageFinishGrade  GarageQualGrade  \
# 1455                7              5.0                2.0              4.0
# 1456                4              5.0                1.0              4.0
# 1457                7              5.0                2.0              4.0
# 1458                7              5.0                1.0              4.0
# 1459                7              5.0                3.0              4.0
#
#       GarageCondGrade  PavedDriveGrade  SaleTypeGrade  SaleConditionGrade  \
# 1455              5.0                3              6                   5
# 1456              5.0                3              6                   5
# 1457              5.0                3              6                   5
# 1458              5.0                3              6                   5
# 1459              5.0                3              6                   5
#
#       SalePrice
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [5 rows x 39 columns]

# %%
df_new1 = df_str

def idx_search(df_new1, num):
    col_name = df_new1.columns[num]
#     for col_name in col_names:
    df1 = pd.DataFrame(df_new1, columns=[col_name,"SalePrice"])  
    df2 = df1.groupby([col_name])["SalePrice"].median().reset_index(name='Median').sort_values('Median').reset_index(drop=True)
    print(df2)

idx_search(df_new1,3)
# Out:
#   LandContour  Median
# 0         Bnk  139400
# 1         Lvl  162900
# 2         Low  190000
# 3         HLS  222250

# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}
heat= df_new.corr()
fig, ax = plt.subplots(figsize=(12,12))         # Sample figsize in inches
sns.heatmap(heat.iloc[:, :], annot=True, linewidths=.5, ax=ax)

# %%
heat["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice             1.000000
# NeighborhoodGrade     0.696158
# ExterQualGrade        0.682639
# KitchenQualGrade      0.659600
# BsmtQualGrade         0.644019
# GarageFinishGrade     0.513105
# FoundationGrade       0.478431
# GarageTypeGrade       0.445945
# MasVnrTypeGrade       0.429020
# HeatingQCGrade        0.427649
# Exterior1stGrade      0.371018
# Exterior2ndGrade      0.362052
# BsmtFinType1Grade     0.354137
# BsmtExposureGrade     0.352958
# MSZoningGrade         0.324610
# SaleTypeGrade         0.297769
# HouseStyleGrade       0.276306
# LotShapeGrade         0.265699
# CentralAirGrade       0.251328
# SaleConditionGrade    0.238111
# ElectricalGrade       0.233590
# RoofStyleGrade        0.233188
# PavedDriveGrade       0.231357
# Condition1Grade       0.167154
# GarageCondGrade       0.162827
# RoofMatlGrade         0.161131
# BsmtCondGrade         0.160658
# LandContourGrade      0.158437
# GarageQualGrade       0.156800
# BldgTypeGrade         0.155368
# LotConfigGrade        0.134475
# ExterCondGrade        0.125332
# HeatingGrade          0.118755
# FunctionalGrade       0.114209
# Condition2Grade       0.093693
# BsmtFinType2Grade     0.086807
# LandSlopeGrade        0.048340
# StreetGrade           0.041036
# UtilitiesGrade        0.014314
# Name: SalePrice, dtype: float64

# %%
var = 'ExterQualGrade'
sns.jointplot(x=var, y="SalePrice", data=df_new)

# %%
def show_viobox(df,col_name):
    print(col_name)
        
    # 각 항목에 대한 빈도 출력 / df2 dataframe 따로 생성
    df2 = pd.DataFrame(df[col_name])
    counts = df2.groupby([col_name]).size().reset_index(name='Counts')
    print(counts)
        
    plt.subplot(121)
    sns.violinplot(x=col_name, y='SalePrice', data=df)
    plt.subplot(122)
    sns.boxplot(x=col_name, y='SalePrice', data=df)
    plt.show()

# %%
show_viobox(df_new,var)
# Out:
# ExterQualGrade
#    ExterQualGrade  Counts
# 0               1      14
# 1               2     906
# 2               3     488
# 3               4      52
