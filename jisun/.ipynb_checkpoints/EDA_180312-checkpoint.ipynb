# %%
# 데이터 전처리

df = pd.read_csv('../train.csv')
df_raw = df.copy()

# Ex~Po의 등급을 가진 변수들은 모두 숫자로 바꿔줌. NA값은 무조건 0으로 만들어줌

cat_num_ls=['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'HeatingQC', 'KitchenQual', 'FireplaceQu', 'GarageQual', 'GarageCond', 'PoolQC', 'SalePrice']

tonum = {"ExterQual": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "ExterCond": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "BsmtQual": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "BsmtCond": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "HeatingQC": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "KitchenQual": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "FireplaceQu": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "GarageQual": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "GarageCond": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "PoolQC": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         
        }

df_raw= df_raw.replace(tonum)

# NA 값 처리

def nan_check(df_raw):
    null_check = df_raw.isnull().sum()
    null_count = pd.DataFrame({'column' : null_check.index, 'NaN' : null_check.values})
    # None 값이 있는 column만 가져옴.
    null_count = null_count.query('NaN > 0')
    return(null_count)

def nan_check2(df_raw):
    null_check = df_raw.isnull().sum()
    null_count = pd.DataFrame({'column' : null_check.index, 'NaN' : null_check.values})
    # None 값이 없는 column만 가져옴.
    null_count = null_count.query('NaN == 0')
    return(null_count)

# nan값이 있는 컬럼 이름을 가진 리스트 (13개)
nan_ls = list(set(nan_check(df_raw)['column']) - set(nan_check2(df_raw)['column']))
nan_ls
# description 직접 보면서 결측값이 뭔지 확인

# NA값이 판단된 카테고리 값에 대해 NA에 N이라는 값을 부여 (=N이라는 클래스를 부여)

fill_na_ls = [['GarageType',
 'MiscFeature',
 'BsmtFinType1',
 'Fence',
 'GarageFinish',
 'BsmtExposure',
 'Alley',
 'BsmtFinType2']
]

for name in fill_na_ls:
    df_raw[name] = df_raw[name].fillna('N')

# 원본 데이터 df
# 전처리 마친 데이터 df_raw

# %%
# 경고창 보이지 않기
import warnings
warnings.filterwarnings('ignore')
# 그래프 크게보기
plt.rcParams["figure.figsize"] = (15,6)

# %matplotlib inline

# %%
df = pd.read_csv('../train.csv')
df_raw = df.copy()

# %% [markdown]
# # 데이터 전처리

# %%
# Ex~Po의 등급을 가진 변수들은 모두 숫자로 바꿔줌. NA값은 무조건 0으로 만들어줌

cat_num_ls=['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'HeatingQC', 'KitchenQual', 'FireplaceQu', 'GarageQual', 'GarageCond', 'PoolQC', 'SalePrice']

tonum = {"ExterQual": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "ExterCond": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "BsmtQual": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "BsmtCond": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "HeatingQC": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "KitchenQual": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "FireplaceQu": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "GarageQual": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "GarageCond": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         "PoolQC": {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, np.nan : 0},
         
        }

df_raw= df_raw.replace(tonum)

# %%
def nan_check(df_raw):
    null_check = df_raw.isnull().sum()
    null_count = pd.DataFrame({'column' : null_check.index, 'NaN' : null_check.values})
    # None 값이 있는 column만 가져옴.
    null_count = null_count.query('NaN > 0')
    return(null_count)

def nan_check2(df_raw):
    null_check = df_raw.isnull().sum()
    null_count = pd.DataFrame({'column' : null_check.index, 'NaN' : null_check.values})
    # None 값이 없는 column만 가져옴.
    null_count = null_count.query('NaN == 0')
    return(null_count)

# %%
# nan값이 있는 컬럼 이름을 가진 리스트 (13개)
nan_ls = list(set(nan_check(df_raw)['column']) - set(nan_check2(df_raw)['column']))
nan_ls
# description 직접 보면서 결측값이 뭔지 확인
# Out:
# ['MasVnrArea',
#  'GarageFinish',
#  'GarageType',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'MasVnrType',
#  'GarageYrBlt',
#  'Fence',
#  'LotFrontage',
#  'Alley',
#  'Electrical',
#  'MiscFeature']

# %%
# NA값이 판단된 카테고리 값에 대해 NA에 N이라는 값을 부여 (=N이라는 클래스를 부여)

fill_na_ls = [['GarageType',
 'MiscFeature',
 'BsmtFinType1',
 'Fence',
 'GarageFinish',
 'BsmtExposure',
 'Alley',
 'BsmtFinType2']
]

for name in fill_na_ls:
    df_raw[name] = df_raw[name].fillna('N')

# %%
nan_check(df_raw)
# Out:
#     NaN       column
# 3   259  LotFrontage
# 25    8   MasVnrType
# 26    8   MasVnrArea
# 42    1   Electrical
# 59   81  GarageYrBlt

# %%
heat= df_raw.corr()
fig, ax = plt.subplots(figsize=(12,12))         # Sample figsize in inches
sns.heatmap(heat.iloc[:, :], annot=True, linewidths=.5, ax=ax)

# %%
heat["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# ExterQual        0.682639
# KitchenQual      0.659600
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# BsmtQual         0.585207
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# FireplaceQu      0.520438
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# HeatingQC        0.427649
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# GarageQual       0.273839
# LotArea          0.263843
# GarageCond       0.263191
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BsmtCond         0.212607
# BedroomAbvGr     0.168213
# PoolQC           0.111696
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# ExterCond        0.018899
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %%
col_sel = heat["SalePrice"].sort_values(ascending=False).index[1:20]

for col_name in col_sel[1:]:
    sns.jointplot(x=col_name, y="SalePrice", data=df_raw)
    plt.show()

# %%
col_no_sel = heat["SalePrice"].sort_values(ascending=False).index[20:]
for col_name in col_no_sel[1:]:
    sns.jointplot(x=col_name, y="SalePrice", data=df_raw)
    plt.show()

# %%
cat_col = list(set(df_raw.columns) - set(heat["SalePrice"].index))
type(cat_col)
# Out:
# list

# %%
def show_viobox(df,col_name):
    print(col_name)
        
    # 각 항목에 대한 빈도 출력 / df2 dataframe 따로 생성
    df2 = pd.DataFrame(df[col_name])
    counts = df2.groupby([col_name]).size().reset_index(name='Counts')
    print(counts)
        
    plt.subplot(121)
    sns.violinplot(x=col_name, y='SalePrice', data=df)
    plt.subplot(122)
    sns.boxplot(x=col_name, y='SalePrice', data=df)
    plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,6)
for col_name in cat_col:
    show_viobox(df_raw, col_name)
# Out:
# Condition1
#   Condition1  Counts
# 0     Artery      48
# 1      Feedr      81
# 2       Norm    1260
# 3       PosA       8
# 4       PosN      19
# 5       RRAe      11
# 6       RRAn      26
# 7       RRNe       2
# 8       RRNn       5
# Fence
#    Fence  Counts
# 0  GdPrv      59
# 1   GdWo      54
# 2  MnPrv     157
# 3   MnWw      11
# 4      N    1179
# SaleCondition
#   SaleCondition  Counts
# 0       Abnorml     101
# 1       AdjLand       4
# 2        Alloca      12
# 3        Family      20
# 4        Normal    1198
# 5       Partial     125
# MiscFeature
#   MiscFeature  Counts
# 0        Gar2       2
# 1           N    1406
# 2        Othr       2
# 3        Shed      49
# 4        TenC       1
# Condition2
#   Condition2  Counts
# 0     Artery       2
# 1      Feedr       6
# 2       Norm    1445
# 3       PosA       1
# 4       PosN       2
# 5       RRAe       1
# 6       RRAn       1
# 7       RRNn       2
# GarageFinish
#   GarageFinish  Counts
# 0          Fin     352
# 1            N      81
# 2          RFn     422
# 3          Unf     605
# MSZoning
#   MSZoning  Counts
# 0  C (all)      10
# 1       FV      65
# 2       RH      16
# 3       RL    1151
# 4       RM     218
# BsmtFinType1
#   BsmtFinType1  Counts
# 0          ALQ     220
# 1          BLQ     148
# 2          GLQ     418
# 3          LwQ      74
# 4            N      37
# 5          Rec     133
# 6          Unf     430
# HouseStyle
#   HouseStyle  Counts
# 0     1.5Fin     154
# 1     1.5Unf      14
# 2     1Story     726
# 3     2.5Fin       8
# 4     2.5Unf      11
# 5     2Story     445
# 6     SFoyer      37
# 7       SLvl      65
# LotShape
#   LotShape  Counts
# 0      IR1     484
# 1      IR2      41
# 2      IR3      10
# 3      Reg     925
# Exterior1st
#    Exterior1st  Counts
# 0      AsbShng      20
# 1      AsphShn       1
# 2      BrkComm       2
# 3      BrkFace      50
# 4       CBlock       1
# 5      CemntBd      61
# 6      HdBoard     222
# 7      ImStucc       1
# 8      MetalSd     220
# 9      Plywood     108
# 10       Stone       2
# 11      Stucco      25
# 12     VinylSd     515
# 13     Wd Sdng     206
# 14     WdShing      26
# Electrical
#   Electrical  Counts
# 0      FuseA      94
# 1      FuseF      27
# 2      FuseP       3
# 3        Mix       1
# 4      SBrkr    1334
# CentralAir
#   CentralAir  Counts
# 0          N      95
# 1          Y    1365
# Neighborhood
#    Neighborhood  Counts
# 0       Blmngtn      17
# 1       Blueste       2
# 2        BrDale      16
# 3       BrkSide      58
# 4       ClearCr      28
# 5       CollgCr     150
# 6       Crawfor      51
# 7       Edwards     100
# 8       Gilbert      79
# 9        IDOTRR      37
# 10      MeadowV      17
# 11      Mitchel      49
# 12        NAmes     225
# 13      NPkVill       9
# 14       NWAmes      73
# 15      NoRidge      41
# 16      NridgHt      77
# 17      OldTown     113
# 18        SWISU      25
# 19       Sawyer      74
# 20      SawyerW      59
# 21      Somerst      86
# 22      StoneBr      25
# 23       Timber      38
# 24      Veenker      11
# LotConfig
#   LotConfig  Counts
# 0    Corner     263
# 1   CulDSac      94
# 2       FR2      47
# 3       FR3       4
# 4    Inside    1052
# PavedDrive
#   PavedDrive  Counts
# 0          N      90
# 1          P      30
# 2          Y    1340
# Foundation
#   Foundation  Counts
# 0     BrkTil     146
# 1     CBlock     634
# 2      PConc     647
# 3       Slab      24
# 4      Stone       6
# 5       Wood       3
# Heating
#   Heating  Counts
# 0   Floor       1
# 1    GasA    1428
# 2    GasW      18
# 3    Grav       7
# 4    OthW       2
# 5    Wall       4
# GarageType
#   GarageType  Counts
# 0     2Types       6
# 1     Attchd     870
# 2    Basment      19
# 3    BuiltIn      88
# 4    CarPort       9
# 5     Detchd     387
# 6          N      81
# BsmtExposure
#   BsmtExposure  Counts
# 0           Av     221
# 1           Gd     134
# 2           Mn     114
# 3            N      38
# 4           No     953
# Exterior2nd
#    Exterior2nd  Counts
# 0      AsbShng      20
# 1      AsphShn       3
# 2      Brk Cmn       7
# 3      BrkFace      25
# 4       CBlock       1
# 5      CmentBd      60
# 6      HdBoard     207
# 7      ImStucc      10
# 8      MetalSd     214
# 9        Other       1
# 10     Plywood     142
# 11       Stone       5
# 12      Stucco      26
# 13     VinylSd     504
# 14     Wd Sdng     197
# 15     Wd Shng      38
# Functional
#   Functional  Counts
# 0       Maj1      14
# 1       Maj2       5
# 2       Min1      31
# 3       Min2      34
# 4        Mod      15
# 5        Sev       1
# 6        Typ    1360
# LandSlope
#   LandSlope  Counts
# 0       Gtl    1382
# 1       Mod      65
# 2       Sev      13
# MasVnrType
#   MasVnrType  Counts
# 0     BrkCmn      15
# 1    BrkFace     445
# 2       None     864
# 3      Stone     128
# BldgType
#   BldgType  Counts
# 0     1Fam    1220
# 1   2fmCon      31
# 2   Duplex      52
# 3    Twnhs      43
# 4   TwnhsE     114
# RoofMatl
#   RoofMatl  Counts
# 0  ClyTile       1
# 1  CompShg    1434
# 2  Membran       1
# 3    Metal       1
# 4     Roll       1
# 5  Tar&Grv      11
# 6  WdShake       5
# 7  WdShngl       6
# Street
#   Street  Counts
# 0   Grvl       6
# 1   Pave    1454
# LandContour
#   LandContour  Counts
# 0         Bnk      63
# 1         HLS      50
# 2         Low      36
# 3         Lvl    1311
# BsmtFinType2
#   BsmtFinType2  Counts
# 0          ALQ      19
# 1          BLQ      33
# 2          GLQ      14
# 3          LwQ      46
# 4            N      38
# 5          Rec      54
# 6          Unf    1256
# Utilities
#   Utilities  Counts
# 0    AllPub    1459
# 1    NoSeWa       1
# Alley
#   Alley  Counts
# 0  Grvl      50
# 1     N    1369
# 2  Pave      41
# SaleType
#   SaleType  Counts
# 0      COD      43
# 1      CWD       4
# 2      Con       2
# 3    ConLD       9
# 4    ConLI       5
# 5    ConLw       5
# 6      New     122
# 7      Oth       3
# 8       WD    1267
# RoofStyle
#   RoofStyle  Counts
# 0      Flat      13
# 1     Gable    1141
# 2   Gambrel      11
# 3       Hip     286
# 4   Mansard       7
# 5      Shed       2

# %%
df_raw2 = df_raw.copy()

# %%
df_raw2['SalePrice'] = df_raw2['SalePrice'].apply(lambda x : np.log(x))

# %%
heat2= df_raw2.corr()
# fig, ax = plt.subplots(figsize=(12,12))         # Sample figsize in inches
# sns.heatmap(heat2.iloc[:, :], annot=True, linewidths=.5, ax=ax)

heat2["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.817184
# GrLivArea        0.700927
# GarageCars       0.680625
# ExterQual        0.678840
# KitchenQual      0.667893
# GarageArea       0.650888
# BsmtQual         0.615804
# TotalBsmtSF      0.612134
# 1stFlrSF         0.596981
# FullBath         0.594771
# YearBuilt        0.586570
# YearRemodAdd     0.565608
# FireplaceQu      0.546362
# GarageYrBlt      0.541073
# TotRmsAbvGrd     0.534422
# Fireplaces       0.489449
# HeatingQC        0.473762
# MasVnrArea       0.430809
# BsmtFinSF1       0.372023
# GarageQual       0.363259
# GarageCond       0.356767
# LotFrontage      0.355878
# WoodDeckSF       0.334135
# OpenPorchSF      0.321053
# 2ndFlrSF         0.319300
# HalfBath         0.313982
# BsmtCond         0.274543
# LotArea          0.257320
# BsmtFullBath     0.236224
# BsmtUnfSF        0.221985
# BedroomAbvGr     0.209044
# ScreenPorch      0.121208
# PoolQC           0.077291
# PoolArea         0.069798
# MoSold           0.057329
# 3SsnPorch        0.054900
# ExterCond        0.049314
# BsmtFinSF2       0.004832
# BsmtHalfBath    -0.005149
# Id              -0.017942
# MiscVal         -0.020021
# OverallCond     -0.036868
# YrSold          -0.037263
# LowQualFinSF    -0.037963
# MSSubClass      -0.073959
# KitchenAbvGr    -0.147548
# EnclosedPorch   -0.149050
# Name: SalePrice, dtype: float64

# %%
col_sel
# Out:
# Index(['OverallQual', 'GrLivArea', 'ExterQual', 'KitchenQual', 'GarageCars',
#        'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'BsmtQual', 'FullBath',
#        'TotRmsAbvGrd', 'YearBuilt', 'FireplaceQu', 'YearRemodAdd',
#        'GarageYrBlt', 'MasVnrArea', 'Fireplaces', 'HeatingQC', 'BsmtFinSF1'],
#       dtype='object')

# %%
col=['GrLivArea', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'TotRmsAbvGrd', 'MasVnrArea', 'OverallQual','BsmtQual','FireplaceQu']# 'SaleCondition', , ]

for i in range(len(col)):
    print(heat["SalePrice"][col[i]])
# Out:
# 0.7086244776126511
# 0.6234314389183598
# 0.6135805515591944
# 0.6058521846919166
# 0.5337231555820238
# 0.4774930470957107
# 0.7909816005838047
# 0.5852071991725148
# 0.5204376059504007

# %%
txt =""
for i in col_sel:
    txt = txt +  ") + scale(" + i
txt
# Out:
# ') + scale(OverallQual) + scale(GrLivArea) + scale(ExterQual) + scale(KitchenQual) + scale(GarageCars) + scale(GarageArea) + scale(TotalBsmtSF) + scale(1stFlrSF) + scale(BsmtQual) + scale(FullBath) + scale(TotRmsAbvGrd) + scale(YearBuilt) + scale(FireplaceQu) + scale(YearRemodAdd) + scale(GarageYrBlt) + scale(MasVnrArea) + scale(Fireplaces) + scale(HeatingQC) + scale(BsmtFinSF1'
